# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliaBalakina/ALATA-2026/blob/main/2026_ALaTA_03_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### The while statement
# A common pattern in assignment statements is an assignment statement that updates
# a variable, where the new value of the variable depends on the old.
#
# x = x + 1 (x+=1)
#
# This means “get the current value of x, add 1, and then update x with the new
# value.”
#
# If you try to update a variable that doesn’t exist, you get an error, because Python
# evaluates the right side before it assigns a value to x:
#
#
# > x = x + 1 (x+=1)
#
# NameError: name 'x' is not defined
#
#
# Before you want to update a variable, you have to initialize it, usually with a simple
# assignment:
#
# x = 0
#
# x = x + 1
#
# Updating a variable by adding 1 is called an **increment**; subtracting 1 is called a
# **decrement**.

# %%
x = 0
x+=1
x+=2
x+=3
print(x)
# Out:
# 6

# %%
x = 0
x+=1
x+=1
x+=1
x+=1
x+=1
x+=1
print(x)
# Out:
# 6

# %%
x-=6
print(x)
# Out:
# 0

# %%
z+=3
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3330474311.py in <cell line: 0>()
# ----> 1 z+=3
#       2 print(z)
#
# NameError: name 'z' is not defined

# %% [markdown]
# In order to perform identical or similar tasks,updating the variables we use **while**.
#
# n = 5
# while n > 0:
# >print(n)
# n = n - 1
#
# print('Stop!')
#
#
# It means, “While
# n is greater than 0, display the value of n and then reduce the value of n by 1.
# When you get to 0, exit the while statement and display the word Stop!”

# %%
n = 5
while n > 0:
    print(n)
    n -= 1
print('Stop!')
# Out:
# 5
# 4
# 3
# 2
# 1
# Stop!

# %% [markdown]
# This type of flow is called ***a loop*** because the third step loops back around to the
# top.
#
# We call each time we execute the body of the loop ***an iteration***.
# For the above loop, we would say, “It had five iterations”, which means that the body of the loop
# was executed five times.
#
# The body of the loop should change the value of one or more variables so that
# eventually the condition becomes false and the loop terminates.
# We call the variable
# that changes each time the loop executes and controls when the loop finishes
# ***the iteration variable***.
# If there is no iteration variable, the loop will repeat forever,
# resulting in ***an infinite loop***.

# %%
while True:
    x = input()
# Out:
# f
# g
# 5
# 6
# 7
# 8
# j
# g
# f
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_796/4192624089.py in <cell line: 0>()
#       1 while True:
# ----> 2     x = input()
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### Task 1
#
# Given a number N. In ascending order, print all the squares of integers that are smaller or equal to N.
#
# INPUT FORMAT:
#
#      N is a positive integer.
#
# OUTPUT FORMAT:
#
#      Squares of integers not greater than (less than or equal to) N in ascending order.
#
#      Input:3
#      Output: 1 (1**2)
#
#      Input:6
#      Output: 1 (1**2), 4 (2**2)

# %%
x=int(input())
i=1
while i**2<=x: #execute the loop until the following condition is True
  print(i**2)
  i+=1
# Out:
# 200
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196

# %% [markdown]
# ### Finishing iterations with **continue** and **break**
# The Python **break statement** stops the loop in which the statement is placed.

# %%
x = int(input())
while x > 0:
    print ('Yes')
    break
# Out:
# -1

# %%
while True:
    x = input()
    if x == '10':
        break
# Out:
# 1
# 3
# 5
# 10

# %% [markdown]
# ## Task 2
# prompt the user for a number (x) (in a loop) and execute the loop till p == x. When p==x, print "Bingo!" and exit the loop.

# %%
p=1
while True:
  x=int(input())
  if p==x:
    print('Bingo!')
    break
# Out:
# 4
# 5
# 7
# 1
# Bingo!

# %% [markdown]
# If you want to finish the current iteration and immediately jump to the next iteration you can use ***the continue
# statement*** to skip to the next iteration without finishing the body of the loop for the current iteration.

# %%
while True:
    x = int(input())
    if x <=0:
        continue
    if x > 0:
        break
print(x)
# Out:
# 0
# -1
# 3
# 3

# %%
while True:
    x = int(input())
    if x <=0:
        continue
    else:
        break
print(x)
# Out:
# 0
# 0
# 0
# -1
# 2
# 2

# %%
while True:
    x = int(input())
    if x <=0:
        continue
    if x > 0:
        print(x)
    break
# Out:
# -1
# 0
# 1
# 1

# %% [markdown]
# ### Task 3
# Given a non-negative integer as an input (a number of sheep), return a string with a murmur: "1 sheep...2 sheep...3 sheep...". Input will always be valid, i.e. no negative integers.
#
# input(3),
#
# output:
#
# 1 sheep...
#
# 2 sheep...
#
# 3 sheep...

# %%
n=int(input())
i=1                 #In this program, i is called a iteration variable.It is used to keep track of the current number of sheep and control how many times the while loop runs.
while i<=n:
  print(i,'sheep...')
  i+=1
# Out:
# 6
# 1 sheep...
# 2 sheep...
# 3 sheep...
# 4 sheep...
# 5 sheep...
# 6 sheep...

# %% [markdown]
# ### Task 4
#
# Write a program that finds the summation of every number from 1 to num. The number will always be a positive integer greater than 0.
#
# For example:
#
# summation(2) -> 3
# (1 + 2)
#
# summation(8) -> 36
# (1 + 2 + 3 + 4 + 5 + 6 + 7 + 8)

# %%
num = int(input('enter a number > 0:  '))
sum = 0
i = 1
while i<=num:
  sum+=i
  print('sum',sum)
  i+=1
  print('iteration',i)
print(sum)
# Out:
# enter a number > 0:  4
# sum 1
# iteration 2
# sum 3
# iteration 3
# sum 6
# iteration 4
# sum 10
# iteration 5
# 10

# %% [markdown]
# # Task 5
#
# Prompt the user for 5 integers each on a new line ( use 'while loop') and then print the sum of these integers .

# %%
sum = 0
i = 0
while i < 5:
  x=int(input())
  sum+=x
  i+=1
print(sum)
# Out:
# 5
# 5
# 5
# 5
# 5
# 25

# %% [markdown]
# **Task 6**
#
# Find the sum of all even numbers from 2 to 100 inclusive.

# %%
sum = 0
i = 2
while i<=100:
  sum = sum + i
  i = i + 2
print (sum)
# Out:
# 2550

# %% [markdown]
# **Task 7 **
#
# How many iterations does the following loops have?
#
# Loop 1
#
# i=0
#
# while i<5:
#
# i=i+1
#
# print ('Hello",i)
#
# Loop 2
#
# i=0
#
# while i<5:
#
# i=i+2
#
# print ('Hello",i)
#
# Loop 3
#
# i=0
#
# while i>5:
#
# i=i+1
#
# print ('Hello",i)
#
# Loop 4
#
# i=10
#
# while i>5:
#
# i=i+1
#
# print ('Hello",i)

# %%
i=0
while i>5:
  i=i+1

# %% [markdown]
# **Task 8**
#
# Find the sum of odd numbers from 1 to N, using the while loop. Enter the natural number N, output the sum.
#
# .... i=1
#
# while i<=N:
#
# sum = sum+i
#
# i=...
#
# .....

# %%
n = int(input("Enter a natural number n: "))
sum = 0
i = 1
while i<=n:
  sum = sum+i
  i+=2
  print(sum)
# Out:
# Enter a natural number n: 5
# 1
# 4
# 9

# %% [markdown]
# **Task 9**
#
# Find the product (*) of all the natural numbers entered. To finish the loop - enter "0".
#
# Input: natural numbers
#
# Output : the product of these numbers
#
# input (3,3,3) - output - 27

# %%
product = 1
while True:
  num = int(input("Enter a number (0 to finish): "))
  if num == 0:
        break
  product *= num
print(product)
# Out:
# Enter a number (0 to finish): 3
# Enter a number (0 to finish): 3
# Enter a number (0 to finish): 3
# Enter a number (0 to finish): 0
# 27

# %%
product = 1
n = int(input())
while n != 0:
    product = product * n
    n = int(input())
print(product)
# Out:
# 0
# 1

# %% [markdown]
# Develop a script that asks users repeatedly for input until they enter 'quit'. After each valid entry, display their input back on screen.

# %%
word = input()
while word != "quit":
  print(word)
  word = input()
# Out:
# gh
# gh
# yy
# yy
# quit

# %%
while True:
  s = input()
  if s == "quit":
    break
  print(s)
# Out:
# gh
# gh
# fg
# fg
# rt
# rt
# quit
