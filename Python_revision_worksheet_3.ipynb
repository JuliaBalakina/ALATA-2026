# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliaBalakina/ALATA-2026/blob/main/Python_revision_worksheet_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Read the code and predict what will be printed.

temperature = 25
if temperature > 20:
    print("Warm")
print("Done")

#What will the program print?
# Out:
# Warm
# Done

# %%
#For each example, decide whether the code inside if will be executed.
#A
number = 10
if number > 5:
    print("A")
#B
number = 10
if number < 5:
    print("B")
#C
age = 18
if age >= 18:
    print("C")
#D
age = 16
if age == 18:
    print("D")

# %%
#Look at the code.

score = 50
if score >= 60:
    print("Passed")
print("The test is over")

#1.What will the program print?
#2.Change only the value of score so that the program also prints:
Passed
The test is over

#3.What is the smallest value of score that will print Passed?

# %%
#The program should print Discount available only when the customer's age is 65 or older.
#Complete the condition.

age = int(input("Enter your age: "))
if age =>65:
    print("Discount available")

# %%
#The program should print Number is positive when the number is greater than 0.
#Something is wrong with the code.

number = -5
if number > 0:
    print("Number is positive")
    print("The number is greater than zero")
    print("Good!")

#1.Will any of the three messages be printed?
#2.Change only the value of number so that all three messages are printed.
#3.What happens if number = 0?

# %%
#Read the code and predict the output.

number = 8
if number > 10:
    print("A")
else:
    print("B")
print("C")

#1.What will the program print?
#2.Now change only the value of number to 15.
#3.What will it print now?

# %%
#Predict the output.

score = 45
if score < 50:
    score = score + 20
else:
    score = score - 10
print(score)

# %%
#Find a value of x that makes the program print each of the following messages.
x=.....
if x >= 10:
    print("A")
else:
    print("B")

#Find:
#1.A value that prints A.
#2.A value that prints B.
#3.What is the smallest integer that prints A?
#4.What is the largest integer that prints B?

# %%
#The program should tell the user whether a number is positive or not positive.

number = int(input("Enter a number: "))
if number > 0:
    print("Positive")
else:
    print("Negative")

#There is a problem when the user enters 0.
#1.What does the program print for 0?
#2.Is that answer correct?
#3.What should the program print instead if the two possible messages are:
#Positive
#Not positive
#Correct the program.

# %%
#Predict the final value of status.

status = "closed"
if status == "open":
    status = "ready"
else:
    status = "waiting"
print(status)

# %%
#Predict the output.

age = 20
if age >= 18 and age < 65:
    print("Working age")
else:
    print("Not working age")

# %%
#A cinema allows a visitor to watch a film if they are 18 or older OR if they have special permission.
#Which condition is correct?

#1.
if age >= 18 and has_permission:
    print("Allowed")
#2.
if age >= 18 or has_permission:
    print("Allowed")
#3.
if age < 18 or has_permission:
    print("Allowed")

# %%
#A user can enter a building if they have an employee card AND either a key OR a security code.
#Which condition is correct?

#1.
if has_card and has_key or has_code:
    print("Access granted")

#2.
if has_card and (has_key or has_code):
    print("Access granted")

#3.

if has_card or (has_key and has_code):
    print("Access granted")

# %%
has_card=False
has_key=True
has_code=False
if has_card==True and has_key==True or has_code==True:
    print("Access granted")

# %%
#Look at the program:

if has_ticket and (is_student or is_teacher):
    print("Free entry")
else:
    print("Ticket required")

#Which rule does the program represent?

#1. A person needs a ticket and must be either a student or a teacher.
#2. A person needs to be a student and have a ticket, or be a teacher.
#3. A person can enter if they are a student or a teacher, regardless of the ticket.

# %%
#A theme park has the following rule:
#A visitor can use a particular attraction if they are
#at least 12 years old AND they are either taller than 140 cm OR accompanied by an adult.

#Complete the program:

age = 11
height = 150
with_adult = False
if (age>11 and height>140) or with_adult==True:
    print("You can use the attraction")
else:
    print("You cannot use the attraction")

# %%
#Prompt the user for three integers.
#Print True if at least two of the three numbers are equal. Otherwise, print False.

a = int(input())
b = int(input())
c = int(input())
if a == b or a == c or b == c:
  print("True")

# %%
#Prompt the user for two integers.
#Print True if exactly one of the numbers is positive.

a = int(input())
b = int(input())
if a>0 or b>0
  print("True")

# %%
#Prompt the user for an integer.
#Print True if the number is between 10 and 50, inclusive.
number = int(input())
print (10<=number<=50) # if 10<=number<=50:  # if number=>10 and number<=50:

# %%
#Prompt the user for an integer.
#Print True if the number is divisible by 3 or divisible by 5.

number = int(input())
print (number % 3 == 0 or number % 5 == 0)  # if number % 3 == 0 or number % 5 == 0:

# %%
#Prompt the user for their age and whether they are a student.
#Print True if the person is:
#under 7 years old, or
#over 65 years old, or a student.

age = int(input())
is_student = input() == "yes"
if age < 7 or age >65 or is_student
print()

# %%
#Prompt the user for three integers.
#Print True if a is greater than both b and c.

a = int(input())
b = int(input())
c = int(input())

print(b<a>c) # if a>b and a>c

# %%
#Prompt the user for three integers.
#Print True if b is between a and c.
#For example:

#a = 10, b = 20, c = 30 → True
#a = 30, b = 20, c = 10 → True
#a = 10, b = 5, c = 30 → False

a = int(input())
b = int(input())
c = int(input())
if (a>b>c) or  (c<b<a):
  print("True")

# %%
#Prompt the user for three integers representing the sides of a triangle.
#Print True if the three sides can form a triangle.
#A triangle is possible if the sum of any two sides is greater than the third side.

a = int(input())
b = int(input())
c = int(input())

print()

# %%
#Prompt the user for two integers: hour and minute.
#Print True if they represent a valid time.
#A valid time has: hour from 0 to 23;minute from 0 to 59.

hour = int(input())
minute = int(input())

print(0<= hour <= 23 and 0<= minute <= 59)

# %%
#Prompt the user for two choices:

player1 = input()
player2 = input()

#Print True if the two players chose the same thing.

print(player1==player2)

# %%
#Prompt the user for three integers.
#Print True if: all three numbers are positive;and at least two of them are equal.
a = int(input())
b = int(input())
c = int(input())
if a>0 and b>0 and c>0 and (a==b or a==c or b==c):
  print("true")
# Out:
# 1
# 0
# 1
