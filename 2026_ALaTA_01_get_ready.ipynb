# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliaBalakina/ALATA-2026/blob/main/2026_ALaTA_01_get_ready.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello")
print (1)
print ('2'+'2'+'fff')
print (1+1)
# Out:
#   File "/tmp/ipykernel_1706/3254639820.py", line 1
#     print ("Hello"
#           ^
# SyntaxError: '(' was never closed

# %%
print (1+1)
# Out:
# 2

# %% [markdown]
# ### Values and Types
#
#
# A **value** is one of the basic things a program works with, like a letter or a number.
#
# The values above are ***1***, ***"2"*** and ***“Hello”***, ***"fff"***
#
#
# These values belong to different types: 1 is an **integer**, and “Hello” is a
# **string**, so called because it contains a “string” of letters.
#
# Strings are enclosed in quotation marks.
#
#
# The print statement also works for integers.
#
#
# Python knows the difference between an integer number and a string.
#
#
# For example “+” means “addition” if something is a number and “concatenate” if something is a string.
#
#
# Python knows what “type” everything is.
# Some operations are prohibited:
#
#
# You cannot add integer "1” to a string
#
#
# We can ask Python what type something is by using **the type() function**.

# %%
print("1"+"1")
# Out:
# 11

# %%
type(1)
# Out:
# int

# %%
type('hello')
# Out:
# str

# %%
k = 'nice'
type (k)
# Out:
# str

# %%
print('Hello' +1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-137199578990> in <cell line: 1>()
# ----> 1 print('Hello' +1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(1+2)
# Out:
# 3

# %%
"ni"+'ce'
# Out:
# 'nice'

# %% [markdown]
# ### Several Types of Numbers
#
# Numbers have two main types
#
# -  **Integers** are whole numbers:
#    -14, -2, 0, 1, 100, 401233
#
#
# -  **Floating Point Numbers** have  decimal parts:  -2.5 , 0.0, 98.6, 14.0
#
#
# There are other number types - they are variations on float and integer

# %%
y = 2
print(type(2))
print(type(y))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# When you put an integer and floating point in an expression, the integer is implicitly converted to a float
#
# You can control this with the built-in functions int() and float()

# %%
int(42.0)
# Out:
# 42

# %%
int (42.2)
# Out:
# 42

# %%
str (2)
# Out:
# '2'

# %%
x = float(42)
print(x)
type(x)
# Out:
# 42.0
# float

# %%
x=int(3.0)
type(x)
# Out:
# int

# %%
i = 42
type(i)
# Out:
# int

# %%
i=42
f = float(i) ### i = 42, f=float(42)
print(f)
type(f)
# Out:
# 42.0
# float

# %%
a = 1
type(a)
# Out:
# int

# %%
a =1
b = str(a) ### b = str (1)
print(type(b))
print(b)
print(str(a)+b)
# Out:
# <class 'str'>
# 1
# 11

# %%
a =8
a = float(a) # 8.0
print(a)
a = str(a) # "8.0"
print(a)
type(a)
# Out:
# 8.0
# 8.0
# str

# %%
b="1"
print(b)
print('1'+ b)  ### "1" and b - strings. That is why concatenation occurs, when two strings merge into one.
# Out:
# 1
# 11

# %%
print (1+int(b)) # 1+1
# Out:
# 2

# %%
print(int ("1"))
print (str (5.78))
# Out:
# 1
# 5.78

# %%
a = int ("1")
b= str (5)
print(a+int(b))
# Out:
# 6

# %%
a = int ("1")
b= str (5.78)
print(a+float(b))
# Out:
# 6.78

# %% [markdown]
# ### Numeric Expressions
#
#
# '+'  Addition
#
# '-'	Subtraction
#
# '*'	Multiplication
#
#
# '/'	Division
#
# '//' Floor division. Always returns integers.
#
#
# '**' Power
#
#
# '%'	Remainder (always non-negative)

# %%
print(7 % 3) ### 7 - (3*2) остаток от целочисленного деления (remainder of integer division)
# Out:
# 1

# %%
11%2 # 11-10 (2*5)
# Out:
# 1

# %%
199%5 # 199 - 195
# Out:
# 4

# %%
print(9.5 / 2)
print(9.5 // 2) # '//' Special operation to stick with integers. It returns an integer answer,
              #rounded strictly down in case of fractional answers.
# Out:
# 4.75
# 4.0

# %%
print(10/3)
print(10//3)
# Out:
# 3.3333333333333335
# 3

# %%
print(139//7)
print(139/7)
# Out:
# 19
# 19.857142857142858

# %% [markdown]
# ### Order of Evaluation
#
# When we string operators together - Python must know which one to do first
#
# This is called “operator precedence”
#
# Which operator “takes precedence” over the others?
#
# x = 1 + 2 ** 3 / 4 * 5
#
# Highest precedence rule to lowest precedence rule:
#
# Parentheses are always respected
#
# Exponentiation (raise to a power)
#
# Multiplication, Division, and Remainder
#
# Addition and Subtraction
#
# Left to right

# %%
x = 1 + 2 ** 3 / 4 * 5         # 1) 2**3 =8, 2)8/4 = 2, 3)2*5 = 10, 4) 1+10 =11
print (int(x))
# Out:
# 11

# %% [markdown]
# ## **Task 1**
# Vasya came up with the number, then he multiplied it by 7  and then reduced it by 3.
# Find Vasya's result using the program if Vasya's number is
# a) 338
# b) 1764

# %%
x=1764
print(x*7-3)
# Out:
# 12345

# %%
1764*7-3
# Out:
# 12345

# %% [markdown]
# ## **Task 2**
# Vasya's new number is 17. Print Vasya's number and the number following his separated by a space.

# %%
x=17
y = x+1
print (x,y)
# Out:
# 17 18

# %%
print( 17, 17+1)
# Out:
# 17 18

# %%
x= '17'
y = '18'
print( x, y)
# Out:
# 17 18

# %%
print ('17', '18')
# Out:
# 17 18

# %%
print ('17', '17'+'1')
# Out:
# 17 171

# %% [markdown]
# # **Task 3**
#
# Complete the program that outputs the arithmetic mean of three integers. Use the formula (a+b+c)/3

# %%
print(int((10+11+12)/3))
# Out:
# 11

# %%
a=int(input ())
b=int(input ())
c=int(input ())
print((a+b+c)/3)
# Out:
# 11
# 12
# 13
# 12.0

# %% [markdown]
# # **Task 4**
#
# Complete the program that outputs the sum of digits for the entered two-digit and three-digit integers.
#
# x=52
# output:7
#
# x=523
# output:10

# %%
x = 52
b = x % 10 ## 52-50 =2
print(b)
a = x // 10  ## 5
print(a)
print(a + b)
# Out:
# 2
# 5
# 7

# %%
x = int(input())
b = x % 10
print(b)
a = x // 10
print(a)
print(a + b)
# Out:
# 24
# 4
# 2
# 6

# %%
x = 523
a = x // 100
print(a)
b = x %100//10
print(b)
c = x % 10
print(c)
print(a + b + c)
# Out:
# 5
# 2
# 3
# 10

# %%
x = int(input())
a = x // 100
print(a)
b = x %100//10
print(b)
c = x % 10
print(c)
print(a + b + c)
# Out:
# 222
# 2
# 2
# 2
# 6

# %% [markdown]
# **Task **
#
# Petya came up with 2 integers and told Vasya first their sum, and then the difference.
#
# Find and print Petya's numbers if he told Vasya
#
# a) 100 and 56
#
# b)2023 and 189

# %%
x+y=100
x-y=56

# %%
a = 100
b=56
x=((a+b)//2)
y=a-x
print(x,y)
# Out:
# 78 22

# %% [markdown]
# ### Converting between types
#
# **int()**     converts anything to integer
#
# **float()**    converts anything to floating point number
#
# **str()**      converts anything to string

# %%
x = str(56.0)
type(x)
# Out:
# str

# %%
x = int('5')
print(x)
print(2 + x)
print(str(5)+2)
print(float(5))
# Out:
# 5
# 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3019288241.py in <cell line: 0>()
#       2 print(x)
#       3 print(2 + x)
# ----> 4 print(str(5)+2)
#       5 print(float(5))
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(type(str(5647)))
# Out:
# <class 'str'>

# %%
x = str(5647)
type(x)
# Out:
# str

# %%
a = str(1+3)
a= str(4)
print(a)
type(a)
# Out:
# 4
# str

# %%
a = float('2'+'-3') #'2-3'
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0181b2e682be> in <cell line: 1>()
# ----> 1 a = float('2'+'-3')
#       2 print(a)
#       3 type(a)
#
# ValueError: could not convert string to float: '2-3'

# %%
a = float('-2'+'3') #'-23'
print(a)
type(a)
# Out:
# -23.0
# float

# %%
print(float('-3'))
# Out:
# -3.0

# %% [markdown]
# ### Task 5 Septermber, 7
#
# Given are an integer 5 and a string '55':
#
# 1. convert a string into an integer
# 2. find the sum of both integers

# %%
x = 5
y = '55'
print(x + int(y))
# Out:
# 60

# %% [markdown]
# # Task 6
#
# Given are two integers  7 and 7
# 1. covert integers into strings
# 2. concatenate two strings

# %%
a = 7
b = 7
print(str(a)+str(b))
# Out:
# 77

# %%
a = str(7)
b = str(7)
print(a+b)
# Out:
# 77

# %%
print (str (7)+ str (7))
# Out:
# 77

# %%
a=7
b=7
print (str(a+b))
# Out:
# 14

# %% [markdown]
# **Task 7**
# 1. Nick decided to type his name 10 times separated by a space.
# 2.Change the program and type any other name 10 times through 2 spaces

# %%
print (('Nick ')*10)
# Out:
# Nick Nick Nick Nick Nick Nick Nick Nick Nick Nick

# %%
print("Avishek  " * 10)
# Out:
# Avishek  Avishek  Avishek  Avishek  Avishek  Avishek  Avishek  Avishek  Avishek  Avishek

# %%
x = "Alex  "
print (x*10)
# Out:
# Alex  Alex  Alex  Alex  Alex  Alex  Alex  Alex  Alex  Alex

# %%
name ='Aya '
print ((name + '!') * 10 )
# Out:
# Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya !

# %%
print((name + "!") * 9 +name)
# Out:
# Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya

# %%
print((name + "!") * 9,name)
# Out:
# Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya !Aya ! Aya

# %% [markdown]
# **Task 8**
#
# Use the program to help Nick type the last name and first name of any friend through 3 spaces.

# %%
print("Avishek  " , "Golder")
# Out:
# Avishek   Golder

# %%
print("Avishek   " + "Golder")
# Out:
# Avishek   Golder

# %%
last_name = 'Rouainia'
first_name = 'Aya'
print(last_name + '   ' + first_name)
# Out:
# Rouainia   Aya

# %% [markdown]
# **Task**
#
# Print a number in which first there are 10 ones, then 9 twos, then 8 threes
#
# Output:111111111122222222233333333

# %%
print('1' * 10 + '2' * 9 + '3' * 8)
# Out:
# 111111111122222222233333333

# %%
print ('1' *10,'2' *9,'3'*8)
# Out:
# 1111111111 222222222 33333333

# %% [markdown]
# **Task**
#
# Print the syllable "kwa" 20 times, the syllables should be separated by a hyphen.
#
# Output: kwa-kwa-kwa-kwa-kwa-etc.

# %%
print(('kwa' + "-") * 19 +'kwa')
print (('kwa-')* 19 +'kwa')
# Out:
# kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa
# kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa

# %%
print (('kwa-')*20)
# Out:
# kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-kwa-

# %% [markdown]
# ### User Input
#
# We can instruct Python to pause and read data from the user using **the input()  function.
#
# !!! The input()  function returns a string !!!

# %%
name = input('Who are you? ')
type(name)
# Out:
# Who are you? Julia
# str

# %%
print('Welcome,', name + '!')
# Out:
# Welcome, Julia!

# %%
print('Welcome,'+ name + '!')
# Out:
# Welcome,Julia!

# %%
x = int(input())
type(x)
# Out:
# 234
# int

# %%
x = input()
type(x)
# Out:
# 123
# str

# %% [markdown]
# ### Converting User Input
# If we want to read a number from the user, we must convert it from a string to a number using a type conversion function.
#
# int(input()) - for integers
#
# float(input()) - for floats

# %%
eu = input ('Distance in km? ')
us = int(eu)/ 1.609344
print ('Distance in miles', us)
# Out:
# Distance in km? 3
# Distance in miles 1.8641135767120018

# %%
eu = int(input ('Distance in km? '))
us = eu/ 1.609344
print ('Distance in miles', us)
# Out:
# Distance in km? 100
# Distance in miles 62.13711922373339

# %%
eu = input ('Distance in km? ')
us = eu/ 1.609344
print ('Distance in miles', us)
# Out:
# Distance in km? 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_895/3187666903.py in <cell line: 0>()
#       1 eu = input ('Distance in km? ')
# ----> 2 us = eu/ 1.609344
#       3 print ('Distance in miles', us)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %% [markdown]
# ### Task 9
#
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
#
# Enter Hours: 35
#
# Enter Rate: 2.75
#
# Pay: 96.25

# %%
hours=float(input('Enter hours '))
rate=float(input("Enter rate "))
gross_pay=hours*rate
print("Pay=",gross_pay)
# Out:
# Enter hours 35
# Enter rate 2.75
# Pay= 96.25

# %%
hours=float(input('Enter hours '))
rate=float(input("Enter rate "))
print("Pay=",hours*rate)
# Out:
# Enter hours 35
# Enter rate 2.75
# Pay= 96.25

# %%
hours=float(input('Enter hours '))
rate=float(input("Enter rate "))
print("Pay="+str(hours*rate))
# Out:
# Enter hours 35
# Enter rate 2.75
# Pay=96.25

# %%
hours, rate=float(input('Enter hours ')), float(input("Enter rate "))
pay=hours*rate
print(pay)
# Out:
# Enter hours 35
# Enter rate 2.75
# 96.25

# %% [markdown]
# ### Task 10
#
# Write a program that asks the user from the keyboard his height in centimeters, his weight in kilograms (each indicator - a new line, in a new query) and returns the following message:
#
# Body mass index: [value].
#
# where  [value] is the calculated value of the body mass index.
#
# The body mass index is calculated in the following way:
#
# BMI=m/h2
#
# where m is body weight in kilograms, h is height in meters.

# %%
a=float(input("enter your height in centimeters:"))
b=float(input("enter your weight in kilograms:"))
c=a/100
bmi=b/(c**2)
print("body mass index:", bmi)
# Out:
# enter your height in centimeters:170
# enter your weight in kilograms:70
# body mass index: 24.221453287197235

# %%
a = float(input ('enter the mass, kg: '))
b = float(input ('enter the height, cm: '))
print ('BMI:',(a/(b/100)**2))
# Out:
# enter the mass, kg: 70
# enter the height, cm: 170
# BMI: 24.221453287197235

# %%
a,b = float(input ('enter the mass, kg: ')),float(input ('enter the height, cm: '))
print ('BMI:',(a/(b/100)**2))
# Out:
# enter the mass, kg: 70
# enter the height, cm: 170
# BMI: 24.221453287197235

# %%
a = float(input ('enter the mass, kg: '))
b = float(input ('enter the height, cm: '))
print ('BMI:',(int(a/(b/100)**2)))
# Out:
# enter the mass, kg: 70
# enter the height, cm: 170
# BMI: 24
